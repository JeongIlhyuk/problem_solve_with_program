# %% [markdown]
# <a href="https://colab.research.google.com/github/explodeTheComputer/ptongmoon/blob/main/%EC%A0%95%EC%9D%BC%ED%98%81%EC%BB%B4%EA%B3%B5%EA%B3%BC%EC%A0%9C1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 과제1 내용
# ![image.png](data:image/png;base64,...)

# %%
# 1
age=int(input('나이입력: '))
if age>=20:
    print('성인입니다.')
else:
    print('성인이 아닙니다.')
# Out:
# 나이입력: 15
# 성인이 아닙니다.

# %%
# 2
age=int(input('나이입력: '))
if age>=70:
    print('경로우대승차권발급')
else:
    print('일반승차권발급')
print('이용해주셔서 감사합니다.')
# Out:
# 나이입력: 70
# 경로우대승차권발급
# 이용해주셔서 감사합니다.

# %%
# 3
height,weight=map(float,input('키, 몸무게 순서대로 공백으로 구분하여 입력: ').split())
if height>=155 and weight>=45:
    print('탑승 가능!')
else:
    print('탑승 금지!!')
# Out:
# 키, 몸무게 순서대로 공백으로 구분하여 입력: 154          45
# 탑승 금지!!

# %%
# 4
PW='Python is Fun'
attempt=0
while attempt<3:
    pw=input('비밀번호입력: ')
    if PW==pw:
        print('로그인 성공')
        break
    attempt+=1
if attempt==3:
    print('실패')
# Out:
# 비밀번호입력: a
# 비밀번호입력: f
# 비밀번호입력: Python is Fun
# 로그인 성공
